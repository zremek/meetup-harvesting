# %%
import meetup.api
import json
import requests
import time
import codecs
import sys
import io

# %% [markdown]
# Warning: *this code does not work!*
#
#
# To make it work you need a meetup.com API token.
# Meetup members can easily get their token at https://secure.meetup.com/meetup_api/key/
#
# Just swap "MY_API_KEY" in a request.get("key=") to the proper token, and you're ready to go.
#
# Data that I got represents meetups in Poland, topic "data science", 2019-06-04.

# %%
ds_groups_29 = requests.get(
    'https://api.meetup.com/find/groups?key=MY_API_KEY&photo-host=public&country=PL&topic_id=102811&radius=100.0&page=200'
                       )
ds_groups_29.json()
# gets 29 groups, while total 86 in Poland https://www.meetup.com/topics/data-science/pl/
# reason is my location - Lodz
# Out:
# [{'score': 1.0,
#   'id': 18729763,
#   'name': 'PyData Warsaw',
#   'status': 'active',
#   'link': 'https://www.meetup.com/PyData-Warsaw/',
#   'urlname': 'PyData-Warsaw',
# ...

# %%
data = ds_groups_29.json()
try:
 to_unicode = unicode
except NameError:
 to_unicode = str
with io.open('ds_groups_29.json', 'w', encoding='utf8') as outfile:
 str_ = json.dumps(data,
 indent=4, sort_keys=True,
 separators=(',', ': '), ensure_ascii=False)
 outfile.write(to_unicode(str_))

# %%
# location changed to Poznan
ds_groups_poznan = requests.get(
    'https://api.meetup.com/find/groups?key=MY_API_KEY&photo-host=public&country=PL&topic_id=102811&radius=100.0&page=200'
                       )
data = ds_groups_poznan.json()
try:
 to_unicode = unicode
except NameError:
 to_unicode = str
with io.open('ds_groups_poznan.json', 'w', encoding='utf8') as outfile:
 str_ = json.dumps(data,
 indent=4, sort_keys=True,
 separators=(',', ': '), ensure_ascii=False)
 outfile.write(to_unicode(str_))

# %%
# location changed to Wroclaw
ds_groups_wroclaw = requests.get(
    'https://api.meetup.com/find/groups?key=MY_API_KEY&photo-host=public&country=PL&topic_id=102811&radius=100.0&page=200'
                       )
data = ds_groups_wroclaw.json()
try:
 to_unicode = unicode
except NameError:
 to_unicode = str
with io.open('ds_groups_wroclaw.json', 'w', encoding='utf8') as outfile:
 str_ = json.dumps(data,
 indent=4, sort_keys=True,
 separators=(',', ': '), ensure_ascii=False)
 outfile.write(to_unicode(str_))

# %%
# location changed to Rzeszow
ds_groups_rzeszow = requests.get(
    'https://api.meetup.com/find/groups?key=MY_API_KEY&photo-host=public&country=PL&topic_id=102811&radius=100.0&page=200'
                       )
data = ds_groups_rzeszow.json()
try:
 to_unicode = unicode
except NameError:
 to_unicode = str
with io.open('ds_groups_rzeszow.json', 'w', encoding='utf8') as outfile:
 str_ = json.dumps(data,
 indent=4, sort_keys=True,
 separators=(',', ': '), ensure_ascii=False)
 outfile.write(to_unicode(str_))

# %%
# location changed to Olsztyn
ds_groups_olsztyn = requests.get(
    'https://api.meetup.com/find/groups?key=MY_API_KEY&photo-host=public&country=PL&topic_id=102811&radius=100.0&page=200'
                       )
data = ds_groups_olsztyn.json()
try:
 to_unicode = unicode
except NameError:
 to_unicode = str
with io.open('ds_groups_olsztyn.json', 'w', encoding='utf8') as outfile:
 str_ = json.dumps(data,
 indent=4, sort_keys=True,
 separators=(',', ': '), ensure_ascii=False)
 outfile.write(to_unicode(str_))

# %%
# location changed to Szczecin
ds_groups_szczecin = requests.get(
    'https://api.meetup.com/find/groups?key=MY_API_KEY&photo-host=public&country=PL&topic_id=102811&radius=100.0&page=200'
                       )
data = ds_groups_szczecin.json()
try:
 to_unicode = unicode
except NameError:
 to_unicode = str
with io.open('ds_groups_szczecin.json', 'w', encoding='utf8') as outfile:
 str_ = json.dumps(data,
 indent=4, sort_keys=True,
 separators=(',', ': '), ensure_ascii=False)
 outfile.write(to_unicode(str_))

# %%
# location changed to Biala Podlaska
ds_groups_bp = requests.get(
    'https://api.meetup.com/find/groups?key=MY_API_KEY&photo-host=public&country=PL&topic_id=102811&radius=100.0&page=200'
                       )
data = ds_groups_bp.json()
try:
 to_unicode = unicode
except NameError:
 to_unicode = str
with io.open('ds_groups_bp.json', 'w', encoding='utf8') as outfile:
 str_ = json.dumps(data,
 indent=4, sort_keys=True,
 separators=(',', ': '), ensure_ascii=False)
 outfile.write(to_unicode(str_))

# %%
# location changed to Koszalin
ds_groups_kosz = requests.get(
    'https://api.meetup.com/find/groups?key=MY_API_KEY&photo-host=public&country=PL&topic_id=102811&radius=100.0&page=200'
                       )
data = ds_groups_kosz.json()
try:
 to_unicode = unicode
except NameError:
 to_unicode = str
with io.open('ds_groups_kosz.json', 'w', encoding='utf8') as outfile:
 str_ = json.dumps(data,
 indent=4, sort_keys=True,
 separators=(',', ': '), ensure_ascii=False)
 outfile.write(to_unicode(str_))

# %%
# location changed to Bielsko Biala
ds_groups_bielsko = requests.get(
    'https://api.meetup.com/find/groups?key=MY_API_KEY&photo-host=public&country=PL&topic_id=102811&radius=100.0&page=200'
                       )
data = ds_groups_bielsko.json()
try:
 to_unicode = unicode
except NameError:
 to_unicode = str
with io.open('ds_groups_bielsko.json', 'w', encoding='utf8') as outfile:
 str_ = json.dumps(data,
 indent=4, sort_keys=True,
 separators=(',', ': '), ensure_ascii=False)
 outfile.write(to_unicode(str_))
